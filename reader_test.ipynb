# %%
from reader_new import Book 
from bs4 import BeautifulSoup

# %%
book_path="./test_books/PP.epub"
book = Book(book_path)
# print(file.toc_entr())
# print(file.toc())
# html="".join(list(file.get_html_chapters().values()))
# soup=BeautifulSoup(html,"xml")

# %%
tocs=book.toc_entr()
ids=[id for name,lvl,id in tocs]
ids
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 tocs=book.toc_entr()
#       2 ids=[id for name,lvl,id in tocs]
#       3 ids
#
# AttributeError: 'EpubBook' object has no attribute 'toc_entr'

# %%
from ebooklib import epub,utils

book=epub.read_epub(book_path)
# for i in (book.get_items()):
    # if isinstance(i,epub.EpubHtml):
    #     print(utils.get_pages(i))
# for i in book.get_items():
    # if isinstance(i,epub.EpubHtml):
        # print(i)
        # soup=BeautifulSoup(i.content)
        # with open() as file: 
    
[(i.href)for i in book.toc]
# Out:
# ['1527083631709950150_1342-h-0.htm.html#pgepubid00002',
#  '1527083631709950150_1342-h-0.htm.html#pgepubid00022',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00028',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00033',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00041',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00046',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00052',
#  '1527083631709950150_1342-h-1.htm.html#pgepubid00062',
#  '1527083631709950150_1342-h-2.htm.html#pgepubid00071',
#  '1527083631709950150_1342-h-2.htm.html#pgepubid00079',
#  '1527083631709950150_1342-h-2.htm.html#pgepubid00086',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00096',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00103',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00106',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00113',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00119',
#  '1527083631709950150_1342-h-3.htm.html#pgepubid00125',
# ...

# %%
file=zipfile.ZipFile(book_path)
BeautifulSoup(file.open(id),'xml').prettify
# Out:
# <bound method Tag.prettify of <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE html PUBLIC "-//W3C//DTD XHTML 1.1//EN" "http://www.w3.org/TR/xhtml11/DTD/xhtml11.dtd">
# <html xml:lang="en" xmlns="http://www.w3.org/1999/xhtml"><head>
# <link href="1865125475437284429_cover.jpg" id="id-8511648632179683800" rel="icon" type="image/x-cover"/>
# <title>
#   The Project Gutenberg eBook of Pride and prejudice, by Jane Austen.
# </title>
# <link href="0.css" rel="stylesheet" type="text/css"/>
# <link href="pgepub.css" rel="stylesheet" type="text/css"/>
# <meta content="Ebookmaker 0.13.4 by Project Gutenberg" name="generator"/>
# </head>
# <body class="x-ebookmaker x-ebookmaker-2"><div class="pg-boilerplate pgheader section" id="pg-header" lang="en" xml:lang="en"><h2 id="pg-header-heading" title="">The Project Gutenberg eBook of <span id="pg-title-no-subtitle" lang="en" xml:lang="en">Pride and Prejudice</span></h2>
# <div>This ebook is for the use of anyone anywhere in the United States and
# ...

# %%
import zipfile

file=zipfile.ZipFile("./test_books/PP.epub")
cont=file.open("META-INF/container.xml")
content_path=BeautifulSoup(cont,'xml').find("rootfile").attrs["full-path"]
opf_content=file.open(content_path)
list(BeautifulSoup(opf_content).spine.descendants)
# Out:
# /tmp/ipykernel_46684/2564404181.py:7: XMLParsedAsHTMLWarning: It looks like you're parsing an XML document using an HTML parser. If this really is an HTML document (maybe it's XHTML?), you can ignore or filter this warning. If it's XML, you should know that using an XML parser will be more reliable. To parse this document as XML, make sure you have the lxml package installed, and pass the keyword argument `features="xml"` into the BeautifulSoup constructor.
#   list(BeautifulSoup(opf_content).spine.descendants)
# ['\n',
#  <itemref idref="coverpage-wrapper" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="pg-header" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="item3" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="item4" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="item5" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="item6" linear="yes"></itemref>,
#  '\n',
#  <itemref idref="item7" linear="yes"></itemref>,
#  '\n',
# ...

# %%
# bodies[1].find_all(attrs={"href":True})
# Out:
# [<a class="reference external" href="https://www.gutenberg.org">www.gutenberg.org</a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-0.htm.html#PREFACE">PREFACE.</a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-0.htm.html#LIST_OF_ILLUSTRATIONS">List of Illustrations.</a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-0.htm.html#Chapter_I">Chapter: I., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_II">II., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_III">III., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_IV">IV., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_V">V., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_VI">VI., </a>,
#  <a class="pginternal" href="1527083631709950150_1342-h-1.htm.html#CHAPTER_VII">VII., </a>,
# ...
